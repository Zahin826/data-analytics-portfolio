# %%
import pandas as pd
import yfinance as yf
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_theme(style="whitegrid")
plt.rcParams['figure.figsize'] = (12, 5)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 2
#       1 import pandas as pd
# ----> 2 import yfinance as yf
#       3 import matplotlib.pyplot as plt
#       4 import seaborn as sns
#
# ModuleNotFoundError: No module named 'yfinance'

# %%
import sys
# !{sys.executable} -m pip install yfinance

# %%
import pandas as pd
import yfinance as yf
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_theme(style="whitegrid")
plt.rcParams['figure.figsize'] = (12, 5)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 2
#       1 import pandas as pd
# ----> 2 import yfinance as yf
#       3 import matplotlib.pyplot as plt
#       4 import seaborn as sns
#
# ModuleNotFoundError: No module named 'yfinance'

# %%
import sys
print("Python being used:", sys.executable)
# Out:
# Python being used: C:\Users\ZAHIN\AppData\Local\Programs\Python\Python313\python.exe

# %%
import pandas as pd
import yfinance as yf
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_theme(style="whitegrid")
plt.rcParams['figure.figsize'] = (12, 5)

# %%
# Define our stocks and time period
tickers = ['AAPL', 'AMZN', 'GOOGL', 'MSFT']

# Download 5 years of daily data
df = yf.download(tickers, start='2019-01-01', end='2026-01-01')

print("Data shape:", df.shape)
print("\nColumns:")
print(df.columns.tolist())
df.head()
# Out:
# [*********************100%***********************]  4 of 4 completed
# Data shape: (1760, 20)
#
# Columns:
# [('Close', 'AAPL'), ('Close', 'AMZN'), ('Close', 'GOOGL'), ('Close', 'MSFT'), ('High', 'AAPL'), ('High', 'AMZN'), ('High', 'GOOGL'), ('High', 'MSFT'), ('Low', 'AAPL'), ('Low', 'AMZN'), ('Low', 'GOOGL'), ('Low', 'MSFT'), ('Open', 'AAPL'), ('Open', 'AMZN'), ('Open', 'GOOGL'), ('Open', 'MSFT'), ('Volume', 'AAPL'), ('Volume', 'AMZN'), ('Volume', 'GOOGL'), ('Volume', 'MSFT')]
# Price           Close                                        High             \
# Ticker           AAPL       AMZN      GOOGL       MSFT       AAPL       AMZN
# Date
# 2019-01-02  37.503731  76.956497  52.301727  94.397156  37.724594  77.667999
# 2019-01-03  33.768074  75.014000  50.853203  90.924477  34.606398  76.900002
# 2019-01-04  35.209610  78.769501  53.461639  95.153305  35.278483  79.699997
# 2019-01-07  35.131248  81.475502  53.355022  95.274643  35.344988  81.727997
# ...

# %%
# Extract only closing prices
close_prices = df['Close'].copy()

print("Close prices shape:", close_prices.shape)
print("\nMissing values:")
print(close_prices.isnull().sum())
close_prices.head()
# Out:
# Close prices shape: (1760, 4)
#
# Missing values:
# Ticker
# AAPL     0
# AMZN     0
# GOOGL    0
# MSFT     0
# dtype: int64
# Ticker           AAPL       AMZN      GOOGL       MSFT
# Date
# 2019-01-02  37.503731  76.956497  52.301727  94.397156
# 2019-01-03  33.768074  75.014000  50.853203  90.924477
# 2019-01-04  35.209610  78.769501  53.461639  95.153305
# 2019-01-07  35.131248  81.475502  53.355022  95.274643
# 2019-01-08  35.800953  82.829002  53.823654  95.965462

# %%
# Save clean data locally
close_prices.to_csv('../data/stock_close_prices.csv')
print("Data saved successfully!")
# Out:
# Data saved successfully!
